# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline 
import re

#nlp
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction import DictVectorizer


from scipy.sparse import hstack
from scipy import sparse

from sklearn.linear_model import Ridge
from sklearn import linear_model

from scipy import math, stats

# %% [markdown]
# # Loading data and cleaning data

# %%
#loading data
train = pd.read_table("/Users/Jpeteyy/PythonScripts/train.tsv", encoding = 'utf-8')
test = pd.read_table("/Users/Jpeteyy/PythonScripts/test.tsv", encoding = 'utf-8')
#test this later 48952

# %%
#splitting categories into multiple buckets
#train['cat1'], train['cat2'], train['cat3'] = train['category_name'].str.split('/', 2).str
for p,q in enumerate(['cat1','cat2','cat3']):
    train[q] = train['category_name'].apply(lambda x: x.split('/')[p] if pd.isnull(x) != True else '')
    
    
#splitting categories into multiple buckets
#train['cat1'], train['cat2'], train['cat3'] = train['category_name'].str.split('/', 2).str
for p,q in enumerate(['cat1','cat2','cat3']):
    test[q] = test['category_name'].apply(lambda x: x.split('/')[p] if pd.isnull(x) != True else '')

# %%
for k in ['item_description', 'name']:
    train[k] = train[k].apply(lambda x: str.lower(x) if type(x) == str else '')
    
    
for k in ['item_description', 'name']:
    test[k] = test[k].apply(lambda x: str.lower(x) if type(x) == str else '')

# %%
#replacing missing values function
def replace_nan(dataframe):
    #dataframe.category_name.fillna(value="missing", inplace=True)
    dataframe.brand_name.fillna(value="missing", inplace=True)
    #dataframe.item_description.fillna(value="missing", inplace=True)
    #dataframe.cat1.fillna(value="missing", inplace=True)
    #dataframe.cat2.fillna(value="missing", inplace=True)
    #dataframe.cat3.fillna(value="missing", inplace=True)
    #dataframe.cat4.fillna(value="missing", inplace=True)
    return (dataframe)

# %%
#passing training data into replacing missing func
train = replace_nan(train)

test = replace_nan(test)

# %%
train.head(2)
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  mlb cincinnati reds t shirt size xl                  3
# 1         1     razer blackwidow chroma keyboard                  3
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts    missing   10.0
# 1  Electronics/Computers & Tablets/Components & P...      Razer   52.0
#
#    shipping                                   item_description         cat1  \
# 0         1                                 no description yet          Men
# 1         0  this keyboard is in great condition and works ...  Electronics
#
#                   cat2                cat3
# 0                 Tops            T-shirts
# 1  Computers & Tablets  Components & Parts

# %%
#cleaning up string fields


#item_description
train['item_description'] = train.item_description.str.lower()
train['item_description'] = train.item_description.replace('[', ' ')
train['item_description'] = train.item_description.replace(']', ' ')
train['item_description'] = train.item_description.replace('[^0-9a-zA-Z]+', ' ', regex = True)
train['item_description'] = train.item_description.replace(" rm ", '', regex = True)
train['item_description'] = train.item_description.replace('[^a-zA-Z0-9 ]', '', regex = True)


#brand_names
train['brand_name'] = train.brand_name.str.lower()
train['brand_name'] = train.brand_name.replace('[^a-zA-Z0-9 ]', '', regex = True)


#item_names
train['name'] = train.name.str.lower()
train['name'] = train.name.replace('[', ' ')
train['name'] = train.name.replace(']', ' ')
train['name'] = train.name.replace('[^0-9a-zA-Z]+', ' ', regex = True)
train['name'] = train.name.replace(' rm ', '')
#train['name'] = train.name.replace('[^a-zA-Z0-9 ]', '', regex = True)


#item_condition_id
train['item_condition_id'] = train.item_condition_id.replace('5','4')


#categories
train['category_name'] = train.category_name.str.lower()
train['cat1'] = train.cat1.str.lower()
train['cat2'] = train.cat2.str.lower()
train['cat3'] = train.cat3.str.lower()
#train['cat4'] = train.cat4.str.lower()

# %%
#cleaning up string fields


#item_description
test['item_description'] = test.item_description.str.lower()
test['item_description'] = test.item_description.replace('[', ' ')
test['item_description'] = test.item_description.replace(']', ' ')
test['item_description'] = test.item_description.replace('[^0-9a-zA-Z]+', ' ', regex = True)
test['item_description'] = test.item_description.replace(" rm ", '', regex = True)
test['item_description'] = test.item_description.replace('[^a-zA-Z0-9 ]', '', regex = True)


#brand_names
test['brand_name'] = test.brand_name.str.lower()
test['brand_name'] = test.brand_name.replace('[^a-zA-Z0-9 ]', '', regex = True)


#item_names
test['name'] = test.name.str.lower()
test['name'] = test.name.replace('[', ' ')
test['name'] = test.name.replace(']', ' ')
test['name'] = test.name.replace('[^0-9a-zA-Z]+', ' ', regex = True)
test['name'] = test.name.replace(' rm ', '')
#train['name'] = train.name.replace('[^a-zA-Z0-9 ]', '', regex = True)


#item_condition_id
test['item_condition_id'] = test.item_condition_id.replace('5','4')


#categories
test['category_name'] = test.category_name.str.lower()
test['cat1'] = test.cat1.str.lower()
test['cat2'] = test.cat2.str.lower()
test['cat3'] = test.cat3.str.lower()
#train['cat4'] = train.cat4.str.lower()

# %%
train.head(2)
# Out:
#    train_id                                 name item_condition_id  \
# 0         0  mlb cincinnati reds t shirt size xl                 3
# 1         1     razer blackwidow chroma keyboard                 3
#
#                                        category_name brand_name  price  \
# 0                                  men/tops/t-shirts    missing   10.0
# 1  electronics/computers & tablets/components & p...      razer   52.0
#
#    shipping                                   item_description         cat1  \
# 0         1                                 no description yet          men
# 1         0  this keyboard is in great condition and works ...  electronics
#
#                   cat2                cat3
# 0                 tops            t-shirts
# 1  computers & tablets  components & parts

# %% [markdown]
# # Extracting additional brands

# %%
#O(n) string search to extract brands
import ahocorasick

# %%
def string_search(dictionary, listStrings, listSubstrings):
    auto = ahocorasick.Automaton()
    for substr in listSubstrings:
        auto.add_word(substr, substr)
    auto.make_automaton()
    
    for idx, astr in enumerate(listStrings):
        seen = set()
        match_count = 0
        for end_ind, found in auto.iter(astr):
            if (found not in seen) and (match_count == 0):
                seen.add(found)
                #print(idx)
                #print(found+ "   " + astr)
                dictionary.update({idx: found})
                match_count +=1
#https://stackoverflow.com/questions/34816775/python-optimal-search-for-substring-in-list-of-strings
#http://ieva.rocks/2016/11/24/keyword-matching-with-aho-corasick/

# %%
#lookup table of missing brand names to index
missing_brand_lookup_train = pd.DataFrame(train[train['brand_name'] == 'missing'].reset_index().train_id)
missing_brand_lookup_train['join_key'] = missing_brand_lookup_train.index.values
#left join on train_id of output = index, and take the id number





#lookup table of missing brand names to index
missing_brand_lookup_test = pd.DataFrame(test[test['brand_name'] == 'missing'].reset_index().test_id)
missing_brand_lookup_test['join_key'] = missing_brand_lookup_test.index.values
#left join on train_id of output = index, and take the id number

# %%
#missing brands in the item name
name_strings_train =  train[train['brand_name'] ==
                        'missing'].reset_index().name.tolist() 
                        #string names where brand_name is null
name_strings_train = [item + ' ' for item in name_strings_train] # add ' ' to prevent missed brands at end of word



#missing brands in the description
desc_strings_train =  train[train['brand_name'] ==
                        'missing'].reset_index().item_description.tolist() 
                        #string names where brand_name is null
desc_strings_train = [item + ' ' for item in desc_strings_train] # add ' ' to prevent missed brands at end of word




#building list of existing brands
brand_substrings_train = train[train['brand_name'] != 
                        'missing'].reset_index().brand_name.tolist() 
                        #list of brand names where brand_name not null
    
brand_substrings_train = list(set(brand_substrings_train)) #de-duping list of brands

brand_substrings_train = [s for s in brand_substrings_train if len(s) > 2] #restricting brand substring length to > 2

if "all" in brand_substrings_train: brand_substrings_train.remove("all") #removing 'all' brand b/c too common of word
if "and" in brand_substrings_train: brand_substrings_train.remove("and") #removing 'all' brand b/c too common of word
if "pink" in brand_substrings_train: brand_substrings_train.remove("pink") #removing 'all' brand b/c too common of word
    
brand_substrings_train.sort(key=len, reverse=True) #sorting on longest string first

brand_substrings_train =  [item + ' ' for item in brand_substrings_train] #add ' ' to prevent misclassifications in middle of words





#initializing dictionaries to collect extracted brand names

brands_from_name_field_train = {}

brands_from_description_field_train = {}

# %%
#missing brands in the item name
name_strings_test =  test[test['brand_name'] ==
                        'missing'].reset_index().name.tolist() 
                        #string names where brand_name is null
name_strings_test = [item + ' ' for item in name_strings_test] # add ' ' to prevent missed brands at end of word



#missing brands in the description
desc_strings_test =  test[test['brand_name'] ==
                        'missing'].reset_index().item_description.tolist() 
                        #string names where brand_name is null
desc_strings_test = [item + ' ' for item in desc_strings_test] # add ' ' to prevent missed brands at end of word




#building list of existing brands
brand_substrings_test = test[test['brand_name'] != 
                        'missing'].reset_index().brand_name.tolist() 
                        #list of brand names where brand_name not null
    
brand_substrings_test = list(set(brand_substrings_test)) #de-duping list of brands

brand_substrings_test = [s for s in brand_substrings_test if len(s) > 2] #restricting brand substring length to > 2

if "all" in brand_substrings_test: brand_substrings_test.remove("all") #removing 'all' brand b/c too common of word
if "and" in brand_substrings_test: brand_substrings_test.remove("and") #removing 'all' brand b/c too common of word
if "pink" in brand_substrings_test: brand_substrings_test.remove("pink") #removing 'all' brand b/c too common of word
    
brand_substrings_test.sort(key=len, reverse=True) #sorting on longest string first

brand_substrings_test =  [item + ' ' for item in brand_substrings_test] #add ' ' to prevent misclassifications in middle of words





#initializing dictionaries to collect extracted brand names

brands_from_name_field_test = {}

brands_from_description_field_test = {}

# %%
#counting number of previous missing brands
previous_brand_count = train[train["brand_name"] != 'missing'].shape[0]
print("There are " + str(previous_brand_count) + " brands present in the training data")
# Out:
# There are 849853 brands present in the training data

# %%
print(previous_brand_count / train.shape[0])
# Out:
# 0.5732431274809701

# %% [markdown]
# # brand extraction from item name

# %%
#brands hiding in name
string_search(brands_from_name_field_train, name_strings_train, brand_substrings_train)


#brands hiding in name
string_search(brands_from_name_field_test, name_strings_test, brand_substrings_test)

# %%
extracted_brands_train = pd.DataFrame(list(brands_from_name_field_train.items()))

extracted_brands_test = pd.DataFrame(list(brands_from_name_field_test.items()))

# %%
extracted_brands_train.columns = ['train_id', 'brand_name']

extracted_brands_train['brand_name'] = extracted_brands_train['brand_name'].map(lambda x: str(x)[:-1])

extracted_brands_test.columns = ['test_id', 'brand_name']

extracted_brands_test['brand_name'] = extracted_brands_test['brand_name'].map(lambda x: str(x)[:-1])

# %%
extracted_brands_train = pd.merge(extracted_brands_train,missing_brand_lookup_train, left_on='train_id', right_on='join_key', how='left')


extracted_brands_test = pd.merge(extracted_brands_test,missing_brand_lookup_test, left_on='test_id', right_on='join_key', how='left')

# %%
train = pd.merge(train, extracted_brands_train, how='left', left_on='train_id', right_on='train_id_y')
train.brand_name_y = train.brand_name_y.fillna('missing')

test = pd.merge(test, extracted_brands_test, how='left', left_on='test_id', right_on='test_id_y')
test.brand_name_y = test.brand_name_y.fillna('missing')

# %%
train['brand_name'] = train[['brand_name_x','brand_name_y']].apply(
    lambda x: x['brand_name_y'] 
    if x['brand_name_x'] == 'missing' 
    else x['brand_name_x'], axis=1)


test['brand_name'] = test[['brand_name_x','brand_name_y']].apply(
    lambda x: x['brand_name_y'] 
    if x['brand_name_x'] == 'missing' 
    else x['brand_name_x'], axis=1)

# %%
train.drop('brand_name_x', axis=1, inplace=True)
train.drop('brand_name_y', axis=1, inplace=True)
train.drop('train_id_x', axis=1, inplace=True)
train.drop('train_id_y', axis=1, inplace=True)
train.drop('join_key', axis=1, inplace=True)


test.drop('brand_name_x', axis=1, inplace=True)
test.drop('brand_name_y', axis=1, inplace=True)
test.drop('test_id_x', axis=1, inplace=True)
test.drop('test_id_y', axis=1, inplace=True)
test.drop('join_key', axis=1, inplace=True)

# %%
train.tail(2)
# Out:
#          train_id                           name item_condition_id  \
# 1482533   1482533         world markets lanterns                 3
# 1482534   1482534  brand new lux de ville wallet                 1
#
#                               category_name  price  shipping  \
# 1482533  home/home décor/home décor accents   45.0         1
# 1482534   women/women's accessories/wallets   22.0         0
#
#                                           item_description   cat1  \
# 1482533  there is 2 of each one that you see so 2 red 2...   home
# 1482534  new with tag red with sparkle firm price no fr...  women
#
#                         cat2                cat3 brand_name
# 1482533           home décor  home décor accents    missing
# 1482534  women's accessories             wallets        lux

# %%
print("Extracted " + str(train[train["brand_name"] != 'missing'].shape[0]  - previous_brand_count) + " brands from item name in training data")
previous_brand_count = train[train["brand_name"] != 'missing'].shape[0]
# Out:
# Extracted 278179 brands from item name in training data

# %% [markdown]
# # brand extraction from item description

# %%
#brands hiding in description
string_search(brands_from_description_field_train, desc_strings_train, brand_substrings_train)


#brands hiding in description
string_search(brands_from_description_field_test, desc_strings_test, brand_substrings_test)

# %%
extracted_brands_train = pd.DataFrame(list(brands_from_description_field_train.items()))
extracted_brands_train.columns = ['train_id', 'brand_name']

extracted_brands_train['brand_name'] = extracted_brands_train['brand_name'].map(lambda x: str(x)[:-1])
extracted_brands_train = pd.merge(extracted_brands_train,missing_brand_lookup_train, left_on='train_id', right_on='join_key', how='left')


extracted_brands_test = pd.DataFrame(list(brands_from_description_field_test.items()))
extracted_brands_test.columns = ['test_id', 'brand_name']

extracted_brands_test['brand_name'] = extracted_brands_test['brand_name'].map(lambda x: str(x)[:-1])
extracted_brands_test = pd.merge(extracted_brands_test,missing_brand_lookup_test, left_on='test_id', right_on='join_key', how='left')

# %%
train = pd.merge(train, extracted_brands_train, how='left', left_on='train_id', right_on='train_id_y')
train.brand_name_y = train.brand_name_y.fillna('missing')

train['brand_name'] = train[['brand_name_x','brand_name_y']].apply(
    lambda x: x['brand_name_y'] 
    if x['brand_name_x'] == 'missing' 
    else x['brand_name_x'], axis=1)
#testing
#train[(train['brand_name_x'] == 'missing') & (train['brand_name'] != 'missing')]




test = pd.merge(test, extracted_brands_test, how='left', left_on='test_id', right_on='test_id_y')
test.brand_name_y = test.brand_name_y.fillna('missing')

test['brand_name'] = test[['brand_name_x','brand_name_y']].apply(
    lambda x: x['brand_name_y'] 
    if x['brand_name_x'] == 'missing' 
    else x['brand_name_x'], axis=1)
#testing
#train[(train['brand_name_x'] == 'missing') & (train['brand_name'] != 'missing')]

# %%
train.drop('brand_name_x', axis=1, inplace=True)
train.drop('brand_name_y', axis=1, inplace=True)
train.drop('train_id_x', axis=1, inplace=True)
train.drop('train_id_y', axis=1, inplace=True)
train.drop('join_key', axis=1, inplace=True)

test.drop('brand_name_x', axis=1, inplace=True)
test.drop('brand_name_y', axis=1, inplace=True)
test.drop('test_id_x', axis=1, inplace=True)
test.drop('test_id_y', axis=1, inplace=True)
test.drop('join_key', axis=1, inplace=True)

# %%
test.tail(2)
# Out:
#         test_id                                  name item_condition_id  \
# 693357   693357                  hi low floral kimono                 2
# 693358   693358  freeship 2 floral scrub tops medium                  2
#
#                         category_name  shipping  \
# 693357       women/swimwear/cover-ups         0
# 693358  women/tops & blouses/t-shirts         1
#
#                                          item_description   cat1  \
# 693357  floral kimono tropical print open front hi low...  women
# 693358  2 floral scrub tops worn less than 5 times eac...  women
#
#                   cat2       cat3 brand_name
# 693357        swimwear  cover-ups       ring
# 693358  tops & blouses   t-shirts    missing

# %%
print("Extracted " + str(train[train["brand_name"] != 'missing'].shape[0]  - previous_brand_count) + " brands from item desc in training data")
# Out:
# Extracted 184545 brands from item desc in training data

# %%
print(train[train.brand_name != 'missing'].shape[0] / train.shape[0])
# Out:
# 0.8853598734599858

# %% [markdown]
# # Grouping data by category and brand

# %%
train['brand_name'] = train.brand_name.replace('missing', np.nan)

brand_summary = train.groupby(['cat1','cat2','cat3','brand_name']).agg({'count'})['price']

# %%
#brand_summary.head(50)

# %%
#renaming columns
brand_summary.rename(columns={'count':'brand_item_count'}, inplace=True)

brand_summary = brand_summary[brand_summary.brand_item_count>100].\
                sort_values(by='brand_item_count', ascending=False).reset_index().copy()

# %%
brand_summary.tail(5)
# Out:
#           cat1                 cat2         cat3    brand_name  \
# 1812     women              dresses  knee-length           que
# 1813     women              jewelry     earrings       silpada
# 1814     women  women's accessories   sunglasses        chanel
# 1815     women             swimwear    two-piece          ping
# 1816  handmade      bags and purses     wristlet  vera bradley
#
#       brand_item_count
# 1812               101
# 1813               101
# 1814               101
# 1815               101
# 1816               101

# %%
#generating random model names for each category
brand_model_num = pd.Series(['brand_'+str(np.random.randint(1,len(brand_summary)*10000)) for i in 
                            range(len(brand_summary))],name='brand_model_num',dtype=str)

brand_summary = pd.concat([brand_summary,brand_model_num], axis=1)

brand_summary.head()
# Out:
#           cat1                    cat2                     cat3  \
# 0        women        athletic apparel  pants, tights, leggings
# 1        women               underwear                     bras
# 2  electronics  video games & consoles                    games
# 3        women          tops & blouses                 t-shirts
# 4        women                   shoes                 athletic
#
#          brand_name  brand_item_count brand_model_num
# 0           lularoe             26184  brand_14880577
# 1  victorias secret             10622   brand_3294579
# 2          nintendo             10517  brand_13820256
# 3              pink              9307  brand_14649503
# 4              nike              8108   brand_4597066

# %%
train= pd.merge(train,brand_summary,how='left',on=['cat1','cat2','cat3','brand_name'])



test= pd.merge(test,brand_summary,how='left',on=['cat1','cat2','cat3','brand_name'])

# %%
#train.head(20)

# %%
#looking at train dataset with categories

# %%
#simple look at train dataset with categories
train.loc[train.brand_model_num != None, ['cat1','cat2','cat3','brand_name','brand_model_num','price']].\
groupby(['cat1','cat2','cat3','brand_name','brand_model_num']).agg({pd.Series.count})['price'].\
reset_index().sort_values(by='count', ascending=False).head(5)
# Out:
#              cat1                    cat2                     cat3  \
# 1056        women        athletic apparel  pants, tights, leggings
# 1686        women               underwear                     bras
# 434   electronics  video games & consoles                    games
# 1612        women          tops & blouses                 t-shirts
# 1357        women                   shoes                 athletic
#
#             brand_name brand_model_num    count
# 1056           lularoe  brand_14880577  26184.0
# 1686  victorias secret   brand_3294579  10622.0
# 434           nintendo  brand_13820256  10517.0
# 1612              pink  brand_14649503   9307.0
# 1357              nike   brand_4597066   8108.0

# %%
#uncategorized items, grouping at category level, where count of items >  100

# %%
cat3_summary = train[pd.isnull(train.brand_model_num) == True].groupby(['cat1','cat2','cat3'])\
                .agg({'count'})['price']
    
cat3_summary.rename(columns={'count':'cat3_item_count'},inplace = True)

cat3_summary = cat3_summary[cat3_summary.cat3_item_count>100].\
                sort_values(by='cat3_item_count',ascending=False).reset_index().copy()

# %%
#generating random model names for each category

cat3_model_num = pd.Series(['cat3_'+str(np.random.randint(1,len(cat3_summary)*10000)) for i in
                           range(len(cat3_summary))], name='cat3_model_num',dtype = str)

cat3_summary = pd.concat([cat3_summary.reset_index(),cat3_model_num], axis = 1)

# %%
cat3_summary.head()
# Out:
#    index   cat1            cat2              cat3  cat3_item_count  \
# 0      0  women  tops & blouses          t-shirts            12905
# 1      1  women  tops & blouses            blouse             9854
# 2      2  women         dresses  above knee, mini             9188
# 3      3    men            tops          t-shirts             8666
# 4      4  women  tops & blouses        tank, cami             8032
#
#   cat3_model_num
# 0   cat3_5922740
# 1   cat3_4468482
# 2   cat3_2564982
# 3    cat3_882241
# 4   cat3_4962965

# %%
train = pd.merge(train,cat3_summary,how='left',on=['cat1','cat2','cat3'])

test = pd.merge(test,cat3_summary, how = 'left', on = ['cat1','cat2','cat3'])

# %%
train['final_model_num'] = train.apply(lambda x: x['cat3_model_num'] if pd.isnull(x['brand_model_num']) == True
                                      else x['brand_model_num'], axis = 1)


test['final_model_num'] = test.apply(lambda x: x['cat3_model_num'] if pd.isnull(x['brand_model_num']) == True
                                      else x['brand_model_num'], axis = 1)

# %%
train['final_item_count'] = train.apply(lambda x: x['cat3_item_count'] if pd.isnull(x['brand_item_count']) == True
                                       else x['brand_item_count'], axis = 1)


train.drop(['brand_item_count','brand_model_num','index', 'cat3_item_count','cat3_model_num'], axis = 1, inplace = True)



test['final_item_count'] = test.apply(lambda x: x['cat3_item_count'] if pd.isnull(x['brand_item_count']) == True
                                       else x['brand_item_count'], axis = 1)


test.drop(['brand_item_count','brand_model_num','index', 'cat3_item_count','cat3_model_num'], axis = 1, inplace = True)

# %%
train.head(3)
# Out:
#    train_id                                 name item_condition_id  \
# 0         0  mlb cincinnati reds t shirt size xl                 3
# 1         1     razer blackwidow chroma keyboard                 3
# 2         2                       ava viv blouse                 1
#
#                                        category_name  price  shipping  \
# 0                                  men/tops/t-shirts   10.0         1
# 1  electronics/computers & tablets/components & p...   52.0         0
# 2                        women/tops & blouses/blouse   10.0         1
#
#                                     item_description         cat1  \
# 0                                 no description yet          men
# 1  this keyboard is in great condition and works ...  electronics
# 2  adorable top with a hint of lace and a key hol...        women
#
#                   cat2                cat3 brand_name final_model_num  \
# 0                 tops            t-shirts        mlb     cat3_882241
# 1  computers & tablets  components & parts      razer    cat3_5610938
# 2       tops & blouses              blouse     target    cat3_4468482
#
#    final_item_count
# 0            8666.0
# 1             807.0
# 2            9854.0

# %%
print(train.isnull().sum())
# Out:
# train_id                  0
# name                      0
# item_condition_id         0
# category_name          6327
# price                     0
# shipping                  0
# item_description          0
# cat1                      0
# cat2                      0
# cat3                      0
# brand_name           169958
# final_model_num       15669
# final_item_count      15669
# dtype: int64

# %%
#train.brand_name.fillna(value = "missing", inplace = True)
#train.category_name.fillna(value="missing", inplace = True)
#train[train.brand_name == 'missing']

# %%
train[train.brand_name == 'victorias secret']
# Out:
#          train_id                                      name item_condition_id  \
# 11             11                    new vs pi k body mists                 1
# 21             21          nwt vs ultimate sports bra 34ddd                 1
# 39             39           victoria secret 34 c corest top                 3
# 111           111   nwt victoria secret bathingsuit bottoms                 1
# 118           118                            pink body mist                 3
# 178           178              vs pink 1 2zip collared sz m                 1
# 182           182        victoria s secret pink night shirt                 2
# 190           190        victoria s secret small bikini top                 2
# 226           226         victoria s secret pj set size med                 3
# 386           386               victoria s secret swim suit                 3
# 391           391  victoria s secret red coral garter skirt                 2
# 395           395                          nwt vs pink tote                 1
# 397           397                  victoria secrets perfume                 1
# 431           431       victoria s secret lounge sweatpants                 2
# 461           461           victoria secret pink sweatpants                 3
# 519           519               vs 36dd dream angels pushup                 3
# 534           534  2 victoria secret logo boy short panty l                 1
# 595           595                 nwt med vs padded bandeau                 1
# 611           611                victoria s secret leggings                 2
# 617           617               sale three pink body mists                  3
# 622           622                victoria secret body spray                 1
# 645           645              vs sport short sleeve hoodie                 3
# 705           705      deep sea cosmetics body butter scrub                 2
# 716           716                36d fs victoria secret bra                 2
# 915                            women/sweaters/cowl neck   43.0         0
# 933                              beauty/fragrance/women    8.0         0
# 947                              beauty/fragrance/women   15.0         0
# 1067                               women/underwear/bras   25.0         1
# ...                                                 ...    ...       ...
# 1481296                          beauty/fragrance/women   18.0         1
# 1481344                        women/swimwear/two-piece   23.0         1
# 1481433                        women/swimwear/two-piece   25.0         1
# 1481438               women/women's accessories/wallets   13.0         1
# 1481456                          beauty/fragrance/women   10.0         1
# 1481618                            women/underwear/bras   20.0         0
# 1481681              women/athletic apparel/sports bras   14.0         0
# 1481716                         women/underwear/panties   20.0         1
# 1481755        vintage & collectibles/collectibles/doll   14.0         1
# 1481771                            women/underwear/bras   32.0         1
# 1481773  women/athletic apparel/pants, tights, leggings   10.0         0
# 1481809           women/women's handbags/backpack style   30.0         1
# 1481919          beauty/bath & body/bathing accessories   15.0         0
# 1481932                        women/swimwear/two-piece   18.0         1
# 1481960                         women/sweaters/full zip   56.0         0
# 1481966            women/athletic apparel/shirts & tops   34.0         0
# 1481983                            women/underwear/bras   25.0         1
# 1481992                            women/underwear/bras   39.0         0
# 1482054                 women/tops & blouses/tank, cami   16.0         1
# 1482126                            women/underwear/bras   11.0         1
# 1482204                            women/underwear/bras   30.0         1
# 1482245              women/athletic apparel/sports bras   12.0         1
# 1482247                            women/shoes/slippers    8.0         1
# 1482257                           beauty/skin care/body   30.0         1
# 1482411                          beauty/fragrance/women   27.0         0
# 1482446                          beauty/fragrance/women   10.0         1
# 1482450                         women/sweaters/crewneck   25.0         0
# 1482475                        women/swimwear/two-piece   33.0         0
# 1482508             women/women's handbags/shoulder bag   21.0         0
# 1482528              women/athletic apparel/sports bras   18.0         1
#
#                                           item_description  \
# 11        5 new vs pink body mists 2 5 oz each fresh cl...
# 21       nwt victoria s secret ultimate sport bra maxim...
# 39       victoria secret 34 c corest top will bundle to...
# 111                    size small nwt bathing suit bottoms
# 118      bombshell eau so sexy bombshell was used a bit...
# 178      price firm don t ask me for the lowest price p...
# 182      from victoria s secret pink plaid and white pa...
# 190          in brand new condition just missing the strap
# 226      victoria s secret hot pink pj set with tank to...
# 386                                   good used condition
# 391      this is a super cute garter skirt from victori...
# 395      new with tags victoria s secret pink logo tote...
# 397                                     no description yet
# 431      black sweatpants by victoria s secret angel lo...
# 461      size xs very goodcondition boot cut sweatpants...
# 519       36dd victoria s secret dream angels with crys...
# 534                   2 pairs free shipping new size large
# 595      this listing is for 1 new medium vs pink padde...
# 611                               like new size s firm pls
# 617      three pink body mists originallyin total onlyp...
# 622      love spell shimmer 8 oz pure seduction red plu...
# 645      good condition no stains rips or holes size is...
# 705      unused still sealed each of these items retail...
# 716      victoria secret very sexy push up front close ...
# 745      brand new in package size large logo low rise ...
# 862                   victoria secret bra great conditions
# 915                       like new army green and white xs
# 933                              new never worn 2 eye mask
# 947      used victoria s secret very sexy touch fragran...
# 1067     worn once body by victoria lined demi not nego...
# ...                                                    ...
# 1481296  free ship new vs scandalous 2 5oz body mist 3 ...
# 1481344  discontinued sold out these are my last sets g...
# 1481433  adorable black bikini with turquoise and green...
# 1481438  new with tag victoria s secret passport holder...
# 1481456   free shipping same fragrance new better than ...
# 1481618              push up bra size 38c great condition
# 1481681  maximum support fully adjustable straps and 3 ...
# 1481716   please read the description box prices are fi...
# 1481755  victoria s secret pink halloween skeleton mini...
# 1481771  hello for sale i have this brand new with tags...
# 1481773                  good condition size xs fits small
# 1481809                                      new with tags
# 1481919         great for a gift sorry i dont pay shipping
# 1481932  brand new victoria s secret white seersucker b...
# 1481960  victoria s secret pink size large fit tts cond...
# 1481966   firm price dont ask 1 victoria s secret large...
# 1481983  brand new without tags they do have marker mar...
# 1481992  nwt check out my closet all sale are final no ...
# 1482054  victoria secrets vsx sexy sport two tank tops ...
# 1482126                       like new very cute size 36 c
# 1482204       new with tags price is firm unless bundling
# 1482245  victorias secret the player sports bra nwt thi...
# 1482247  super cute vs slippers medium fits size 7 good...
# 1482257                                 never used 4 total
# 1482411                      opened but never used 1 7 oz
# 1482446  victoria secrets bundle was rarely used bath a...
# 1482450  worn but still in very nice condition no rips ...
# 1482475  i do combine shipping let s bundle new with ta...
# 1482508                                      new with tags
# 1482528  purple and paisley victoria s secret tankini s...
#
#                            cat1                 cat2                     cat3  \
# 11                       beauty            fragrance                    women
# 21                        women     athletic apparel              sports bras
# 39                        women            underwear                     bras
# 111                       women             swimwear                two-piece
# 118                      beauty            fragrance                    women
# 178                       women             sweaters                 collared
# 182                       women       tops & blouses                    other
# 190                       women             swimwear                two-piece
# 226                       women                other                    other
# 386                       women             swimwear                two-piece
# 391                       women            underwear                  panties
# 395                       women     women's handbags         totes & shoppers
# 397                      beauty            fragrance                    women
# 431                       women     athletic apparel  pants, tights, leggings
# 461                       women     athletic apparel      tracksuits & sweats
# 519                       women            underwear                     bras
# 534                       women            underwear                  panties
# 595                       women                other                    other
# 611                       women     athletic apparel  pants, tights, leggings
# 617                      beauty            fragrance                    women
# 622                      beauty            fragrance                    women
# 645                       women             sweaters                   hooded
# 705                      beauty            skin care                     body
# 716                       women            underwear                     bras
# 745                       women            underwear                  panties
# 862                       women            underwear                     bras
# 915                       women             sweaters                cowl neck
# 933                      beauty            fragrance                    women
# 947                      beauty            fragrance                    women
# 1067                      women            underwear                     bras
# ...                         ...                  ...                      ...
# 1481296                  beauty            fragrance                    women
# 1481344                   women             swimwear                two-piece
# 1481433                   women             swimwear                two-piece
# 1481438                   women  women's accessories                  wallets
# 1481456                  beauty            fragrance                    women
# 1481618                   women            underwear                     bras
# 1481681                   women     athletic apparel              sports bras
# 1481716                   women            underwear                  panties
# 1481755  vintage & collectibles         collectibles                     doll
# 1481771                   women            underwear                     bras
# 1481773                   women     athletic apparel  pants, tights, leggings
# 1481809                   women     women's handbags           backpack style
# 1481919                  beauty          bath & body      bathing accessories
# 1481932                   women             swimwear                two-piece
# 1481960                   women             sweaters                 full zip
# 1481966                   women     athletic apparel            shirts & tops
# 1481983                   women            underwear                     bras
# 1481992                   women            underwear                     bras
# 1482054                   women       tops & blouses               tank, cami
# 1482126                   women            underwear                     bras
# 1482204                   women            underwear                     bras
# 1482245                   women     athletic apparel              sports bras
# 1482247                   women                shoes                 slippers
# 1482257                  beauty            skin care                     body
# 1482411                  beauty            fragrance                    women
# 1482446                  beauty            fragrance                    women
# 1482450                   women             sweaters                 crewneck
# 1482475                   women             swimwear                two-piece
# 1482508                   women     women's handbags             shoulder bag
# 1482528                   women     athletic apparel              sports bras
#
#                brand_name final_model_num  final_item_count
# 11       victorias secret   brand_5313926            5694.0
# 21       victorias secret  brand_12536269            2368.0
# 39       victorias secret   brand_3294579           10622.0
# 111      victorias secret   brand_4691590            3884.0
# 118      victorias secret   brand_5313926            5694.0
# 178      victorias secret    brand_191677             107.0
# 182      victorias secret    brand_489942             137.0
# 190      victorias secret   brand_4691590            3884.0
# 226      victorias secret  brand_16582891             857.0
# 386      victorias secret   brand_4691590            3884.0
# 391      victorias secret    brand_749395            2707.0
# 395      victorias secret   brand_4227362            1761.0
# 397      victorias secret   brand_5313926            5694.0
# 431      victorias secret  brand_15109261            2700.0
# 461      victorias secret  brand_11210252             782.0
# 519      victorias secret   brand_3294579           10622.0
# 534      victorias secret    brand_749395            2707.0
# 595      victorias secret  brand_16582891             857.0
# 611      victorias secret  brand_15109261            2700.0
# 617      victorias secret   brand_5313926            5694.0
# 622      victorias secret   brand_5313926            5694.0
# 645      victorias secret   brand_8486597             992.0
# 705      victorias secret    brand_181959            1001.0
# 716      victorias secret   brand_3294579           10622.0
# 745      victorias secret    brand_749395            2707.0
# 862      victorias secret   brand_3294579           10622.0
# 915      victorias secret    cat3_3228527             361.0
# 933      victorias secret   brand_5313926            5694.0
# 947      victorias secret   brand_5313926            5694.0
# 1067     victorias secret   brand_3294579           10622.0
# ...                   ...             ...               ...
# 1481296  victorias secret   brand_5313926            5694.0
# 1481344  victorias secret   brand_4691590            3884.0
# 1481433  victorias secret   brand_4691590            3884.0
# 1481438  victorias secret  brand_15175135             338.0
# 1481456  victorias secret   brand_5313926            5694.0
# 1481618  victorias secret   brand_3294579           10622.0
# 1481681  victorias secret  brand_12536269            2368.0
# 1481716  victorias secret    brand_749395            2707.0
# 1481755  victorias secret    cat3_4076272             504.0
# 1481771  victorias secret   brand_3294579           10622.0
# 1481773  victorias secret  brand_15109261            2700.0
# 1481809  victorias secret   brand_4209396             436.0
# 1481919  victorias secret   brand_1081553             158.0
# 1481932  victorias secret   brand_4691590            3884.0
# 1481960  victorias secret    brand_877366             408.0
# 1481966  victorias secret   brand_1085194             407.0
# 1481983  victorias secret   brand_3294579           10622.0
# 1481992  victorias secret   brand_3294579           10622.0
# 1482054  victorias secret   brand_7665860            1067.0
# 1482126  victorias secret   brand_3294579           10622.0
# 1482204  victorias secret   brand_3294579           10622.0
# 1482245  victorias secret  brand_12536269            2368.0
# 1482247  victorias secret  brand_18038814             216.0
# 1482257  victorias secret    brand_181959            1001.0
# 1482411  victorias secret   brand_5313926            5694.0
# 1482446  victorias secret   brand_5313926            5694.0
# 1482450  victorias secret  brand_10741881             717.0
# 1482475  victorias secret   brand_4691590            3884.0
# 1482508  victorias secret   brand_7801601             195.0
# 1482528  victorias secret  brand_12536269            2368.0
#
# [48238 rows x 13 columns]

# %%
train.brand_name.fillna(value = "missing", inplace = True)
train.category_name.fillna(value="missing", inplace = True)

test.brand_name.fillna(value = "missing", inplace = True)
test.category_name.fillna(value="missing", inplace = True)

# %% [markdown]
# # Removing brand noise from item descriptions and names where model is at brand level

# %% [markdown]
# # Modeling

# %%
#3 part plan to improve model: 
#1 - missing models < 100 and models w no categories. model is predicting no categories, not predicting < 100
#2 - running entire model with testing data and submitting kernel.
#3 - improving poor categories with mean/median?

# %%
#stop word list to remove
my_stopword_list = ['and','to','the','of', 'a','are','for','you','or','it']

# %%
#testing mse
import math
def rmsle(y_test, y_pred):
    assert len(y_test) == len(y_pred)
    to_sum = [(math.log(y_pred[i] + 1) - math.log(y_test[i] + 1)) ** 2.0 for i,pred in enumerate(y_pred)]
    return (sum(to_sum) * (1.0/len(y_test))) ** 0.5

# %%
classifiers = [
    #svm.SVR(),
    Ridge(alpha=2, random_state=241),
    linear_model.SGDRegressor(),
    #linear_model.BayesianRidge(),
    #linear_model.LassoLars(),
    #linear_model.ARDRegression(),
    linear_model.PassiveAggressiveRegressor(),
    #linear_model.TheilSenRegressor(),
    linear_model.LinearRegression()
    ]

vectorizer = TfidfVectorizer(ngram_range = (1,2), stop_words=my_stopword_list)#, max_features = 50)
#http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html

# %%
#extracting model number where categories are null, so that we can use brands as features
model_no_cat_train = str(set(train[train.category_name == 'missing']['final_model_num'].values))

#extracting model number where categories are null, so that we can use brands as features
model_no_cat_test = str(set(test[test.category_name == 'missing']['final_model_num'].values))

# %%
train.head(2)
# Out:
#    train_id                                 name item_condition_id  \
# 0         0  mlb cincinnati reds t shirt size xl                 3
# 1         1     razer blackwidow chroma keyboard                 3
#
#                                        category_name  price  shipping  \
# 0                                  men/tops/t-shirts   10.0         1
# 1  electronics/computers & tablets/components & p...   52.0         0
#
#                                     item_description         cat1  \
# 0                                 no description yet          men
# 1  this keyboard is in great condition and works ...  electronics
#
#                   cat2                cat3 brand_name final_model_num  \
# 0                 tops            t-shirts        mlb     cat3_882241
# 1  computers & tablets  components & parts      razer    cat3_5610938
#
#    final_item_count
# 0            8666.0
# 1             807.0

# %%
test_id = []
price_prediction = []

np_array_train = train.final_model_num.unique()
np_clean_train = [x for x in np_array_train if str(x) != 'nan']

np_array_test = test.final_model_num.unique()
np_clean_test = [x for x in np_array_test if str(x) != 'nan']

for model in np_clean_train:
    
    vectorizer1 = TfidfVectorizer(ngram_range = (1,2), stop_words=my_stopword_list)
    vectorizer2 = TfidfVectorizer(ngram_range = (1,2), stop_words=my_stopword_list)
    if model == None:
        continue
    else:
        print(model)
        train1 = train[train.final_model_num == model]
        
        X_tfidf = vectorizer1.fit_transform(train1['item_description'].values)
        X_tfidf2 = vectorizer2.fit_transform(train1['name'].values)
        #enc = DictVectorizer()


        if (model[:4] == 'cat3') or (model == model_no_cat_train):

            #adding dummy variable matrix for category items
            dummies = pd.get_dummies(train1['brand_name']).as_matrix()
            
            X = hstack([
                    #sparse.csr_matrix(dummies), 
                    X_tfidf,
                    X_tfidf2,
                    np.vstack(train1.shipping.values),
                    np.vstack(train1.item_condition_id.astype(int))
                    ])
        else:
            X = hstack([
                    X_tfidf, 
                    X_tfidf2,
                    np.vstack(train1.shipping.values),
                    np.vstack(train1.item_condition_id.astype(int))
                   ])


        y = train1.price

        from sklearn.model_selection import train_test_split
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=242)

        d = {}
        for idx, item in enumerate(classifiers):
            #print(type(item))
            clf = item
            clf.fit(X_train, y_train)

            #clf = Ridge(alpha=2, random_state=241)

            ## train model on data
            #clf.fit(X_train, y_train)

            y_pred = clf.predict(X_test)

            y_pred[y_pred < 0] = 0

            score = rmsle(y_test.values,y_pred)

            c = {str(idx) : score}
            d.update(c)
            #print(score)

            #print("Brand: " + str(brand)  +  "\n Model: " +  "\n rmsle = " + str(score))

        #lowest rmsle
        key_min = min(d.keys(), key=(lambda k: d[k]))
        #print(key_min)
        
        clf = classifiers[int(key_min)]
        clf.fit(X_train, y_train)

            #clf = Ridge(alpha=2, random_state=241)

            ## train model on data
            #clf.fit(X_train, y_train)

        y_pred = clf.predict(X_test)

        y_pred[y_pred < 0] = 0
        
        print(rmsle(y_test.values,y_pred))
        #y['pred'] = y_pred
        
        
        if test[test.final_model_num == model].shape[0] == 0:
            continue
        else:
            test1 = test[test.final_model_num == model]
            
            X_tfidf = vectorizer1.transform(test1['item_description'].values)
            X_tfidf2 = vectorizer2.transform(test1['name'].values)
            
            if (model[:4] == 'cat3') or (model == model_no_cat_test):
                
                #adding dummy variable matrix for category items
                #dummies = pd.get_dummies(test1['brand_name']).as_matrix()
            
                X = hstack([
                    #sparse.csr_matrix(dummies), 
                    X_tfidf,
                    X_tfidf2,
                    np.vstack(test1.shipping.values),
                    np.vstack(test1.item_condition_id.astype(int))
                    ])
            else:
                X = hstack([
                    X_tfidf, 
                    X_tfidf2,
                    np.vstack(test1.shipping.values),
                    np.vstack(test1.item_condition_id.astype(int))
                    ])
                
            y_pred = clf.predict(X)

            y_pred[y_pred < 0] = 0

            test1['predicted_price'] = y_pred
            
            test_id.extend(test1.test_id.values.tolist())
            price_prediction.extend(test1.predicted_price.tolist())
# Out:
# cat3_882241
# /Users/Jpeteyy/anaconda/lib/python3.5/site-packages/sklearn/feature_extraction/text.py:1028: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# 0.5629019966617249
# /Users/Jpeteyy/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# cat3_5610938
# 0.891368186512889
# cat3_4468482
# 0.47620868018232765
# cat3_315695
# 0.519687859945431
# cat3_3013512
# 0.6065812300650295
# cat3_4218968
# 0.7014438379939804
# brand_17146625
# 0.5110142467906651
# cat3_3678185
# 0.50080568191401
# brand_3924131
# 0.3886260205637686
# cat3_4076272
# 0.6878057395112356
# brand_6998502
# 0.4229350550168437
# brand_5313926
# 0.4620444078133834
# brand_9929101
# 0.47190431527564203
# cat3_5740672
# 0.5203961525730885
# brand_9745816
# 0.4110236719391259
# brand_11515394
# 0.4754073334740014
# brand_4359090
# 0.335250882364555
# cat3_5959467
# 0.5862468716994598
# brand_1598597
# 0.5478746124268756
# brand_9620785
# 0.28472661743493627
# cat3_334662
# 0.5962452535781947
# brand_3533396
# 0.15081257924034489
# brand_1362498
# 0.5047644685584544
# brand_11282394
# 0.449485049451397
# brand_9388215
# 0.22872575559267508
# brand_14472189
# 0.6127356401404975
# brand_15724904
# 0.5414067732937318
# brand_9975585
# 0.4602258911192024
# brand_14426274
# 0.4211239118827464
# brand_8785891
# 0.4031029007758036
# brand_191712
# 0.4589346247871512
# brand_3538870
# 0.3310713901247516
# brand_17101086
# 0.3434956997136271
# brand_6016843
# 0.4970768065024835
# brand_12443062
# 0.5905650716050063
# brand_364402
# 0.5708398268301018
# brand_13062518
# 0.5226904483751227
# brand_4616953
# 0.3087050772748166
# brand_10243560
# 0.5438766840328162
# brand_6493268
# 0.383856489558864
# brand_2368041
# 0.4597207395985488
# brand_16747960
# 0.5661494872849154
# brand_600326
# 0.36811162541123327
# brand_16836083
# 0.4129332851187312
# brand_11672003
# 0.23913831852277073
# brand_7565113
# 0.3424229059104507
# brand_16675474
# 0.5208454992404384
# brand_2392667
# 0.3087365314981466
# brand_9402820
# 0.34757338467621873
# brand_6756147
# 0.5923004484042622
# brand_15303030
# 0.428213737560382
# brand_786511
# 0.6812436760762696
# brand_252010
# 0.4964913436449924
# brand_3843379
# 0.3087582396203043
# brand_14808315
# 0.45340287581411615
# brand_12450221
# 0.4777072670177322
# brand_11640707
# 0.435138843807599
# brand_112988
# 0.3865684624544092
# brand_10557383
# 0.7993072941411343
# brand_16022295
# 0.6529448387202899

# %%
train.final_model_num.fillna(value="missing", inplace = True)

# %%
no_model_no_brand = train[(train.final_model_num == 'missing') & (train.brand_name == 'missing')]\
                    .groupby(['cat1','cat2','cat3'])['price'].mean().reset_index().copy()
    
no_model_no_brand.rename(columns={'price': 'median_price'}, inplace=True)

#no_model_no_brand['final_model_num_no_mod_no_brnd'] = pd.Series(['cat3_'+str(np.random.randint(1,len(no_model_no_brand)*10000)) for i in
#                           range(len(no_model_no_brand))], dtype = str)

# %%
no_model_w_brand = train[(train.final_model_num == 'missing') & (train.brand_name != 'missing')]\
                    .groupby(['cat1','cat2','cat3','brand_name'])['price'].mean().reset_index().copy()

no_model_w_brand.rename(columns={'price':'median_price'},inplace = True)

#no_model_w_brand ['final_model_num_no_mod_w_brnd'] = pd.Series(['cat3_'+str(np.random.randint(1,len(no_model_w_brand)*10000)) for i in
#                           range(len(no_model_w_brand))], dtype = str)

# %%
train = pd.merge(train, no_model_no_brand, how= 'left',on = ['cat1','cat2','cat3'])
train = pd.merge(train, no_model_w_brand, how= 'left',on = ['cat1','cat2','cat3','brand_name'])

test = pd.merge(test, no_model_no_brand, how = 'left', on = ['cat1','cat2','cat3'])
test = pd.merge(test, no_model_w_brand, how = 'left', on = ['cat1','cat2','cat3','brand_name'])

# %%
#train.drop(['median_price'], axis = 1, inplace = True)

# %%
train['median_price'] = train.apply(lambda x: x['median_price_x'] if (x['final_model_num'] == 'missing'
                                        and str(x['median_price_y']) == 'nan')
                                      else x['median_price_y']
                                        , axis = 1)

#train['median_price'] = train.median_price_x.combine_first(train.median_price_y)

train.drop(['median_price_x','median_price_y'], inplace = True, axis = 1)          


test['median_price'] = test.apply(lambda x: x['median_price_x'] if (x['final_model_num'] == 'missing'
                                        and str(x['median_price_y']) == 'nan')
                                      else x['median_price_y']
                                        , axis = 1)

#train['median_price'] = train.median_price_x.combine_first(train.median_price_y)   

test.drop(['median_price_x','median_price_y'], inplace = True, axis = 1)

# %%
#to do's:
#median/avg for non brand or category items
#submit kernel
#nn, sentiment/meaning, word2vec
#median or avg to replace worst 
#one hot encoding dummies for brand name in categories, test submission or before/after error in a new column? % diff?
#???

# %%
test_ids = np.array(test_id)
price_predictions = np.array(price_prediction)

predicted_cats_brands = pd.DataFrame({'test_id' : test_id, 'price_prediction' : price_predictions})

# %%
predicted_cats_brands.head(5)
# Out:
#    price_prediction  test_id
# 0         20.183670      206
# 1         12.730487      348
# 2         20.240994      829
# 3         28.135452      846
# 4         41.047783      931

# %%
test.head(5)
# Out:
#    test_id                                     name item_condition_id  \
# 0        0   breast cancer i fight like a girl ring                 1
# 1        1  25 pcs new 7 5 x12 kraft bubble mailers                 1
# 2        2                                coach bag                 1
# 3        3                            floral kimono                 2
# 4        4                         life after death                 3
#
#                                     category_name  shipping  \
# 0                             women/jewelry/rings         1
# 1         other/office supplies/shipping supplies         1
# 2  vintage & collectibles/bags and purses/handbag         1
# 3                         women/sweaters/cardigan         0
# 4             other/books/religion & spirituality         1
#
#                                     item_description                    cat1  \
# 0                                             size 7                   women
# 1  25 pcs new 7 5 x12 kraft bubble mailers lined ...                   other
# 2   brand new coach bag bought forat a coach outlet   vintage & collectibles
# 3   floral kimono never worn lightweight and perf...                   women
# 4  rediscovering life after the loss of a loved o...                   other
#
#               cat2                     cat3 brand_name final_model_num  \
# 0          jewelry                    rings       ring   brand_9872518
# 1  office supplies        shipping supplies        elf  brand_14780243
# 2  bags and purses                  handbag      coach  brand_17372476
# 3         sweaters                 cardigan    missing    cat3_3891471
# 4            books  religion & spirituality       ring    cat3_1763646
#
#    final_item_count  median_price
# 0            3168.0           NaN
# 1             773.0           NaN
# 2             172.0           NaN
# 3            4439.0           NaN
# 4             279.0           NaN

# %%
test_final = pd.merge(test[['test_id','median_price']],predicted_cats_brands, how = 'left', on = 'test_id' )

# %%
test_final['price_prediction'] = test_final.price_prediction.combine_first(test_final.median_price)

# %%
test_final.price_prediction.fillna(value=10, inplace=True)

# %%
test_final.rename(columns={'price_prediction':'price'}, inplace=True)

# %%
test_final.head()
# Out:
#    test_id  median_price      price
# 0        0           NaN   7.350082
# 1        1           NaN  15.185819
# 2        2           NaN  56.259712
# 3        3           NaN  10.367929
# 4        4           NaN   8.098345

# %%
test_final[['test_id','price']].to_csv('/Users/Jpeteyy/Desktop/mercari_sub.csv', index = False)

# %%
test_final.head()
# Out:
#    test_id  median_price      price
# 0        0           NaN   7.350082
# 1        1           NaN  15.185819
# 2        2           NaN  56.259712
# 3        3           NaN  10.367929
# 4        4           NaN   8.098345
